# %%
# %pip install iFeatureOmegaCLI
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import iFeatureOmegaCLI

# %%
print(iFeatureOmegaCLI.iLigand.__doc__)
# Out:
#     # Running examples:
#     # import iFeatureOmegaCLI
#     >>> import iFeatureOmegaCLI
#
#     # create a instance
#     >>> ligand = iFeatureOmegaCLI.iLigand("./data_examples/Chemical_SMILES.txt")
#
#     # display available feature descriptor methods
#     >>> ligand.display_feature_types()
#
#     # calculate feature descriptors. Take "Constitution" as an example.
#     >>> ligand.get_descriptor("Constitution")
#
#     # display the feature descriptors
#     >>> print(ligand.encodings)
#
#     # save feature descriptors
#     >>> ligand.to_csv("Ligand_constitution.csv", "index=False", header=False)

# %%
import pandas as pd

# %%
df = pd.read_csv("04_single_vs_multi_function_test_73.csv")
df
# Out:
#         Sample ID                                             SMILES  Label
# 0   >Positive_137  CC(C)=CCCC(C)(OC1OC(COC2OC(CO)C(O)C(OC3OCC(O)C...      1
# 1   >Positive_138  CC(=CC(O)C(O)C(C)(C)O)C1CCC2(C)C1C(O)CC1C3(C)C...      1
# 2   >Positive_139  C=C(C)C(O)CCC(C)(OC1OC(COC2OC(CO)C(O)C2O)C(O)C...      1
# 3   >Positive_140  C=C(C)C(O)CCC(C)(OC1OC(COC2OCC(O)C(O)C2O)C(O)C...      1
# 4   >Positive_141  CCCCOC(=O)C1OC(OC2CCC3(C)C(CCC4(C)C3CC=C3C5CC(...      1
# ..            ...                                                ...    ...
# 68  >Negative_188  CC1(C)CCC2(C(=O)OC3OC(CO)C(O)C(O)C3O)CCC3(C)C(...      0
# 69  >Negative_189  CC(C)=CCCC(C)(O)C1CCC2(C)C1C(O)CC1C3(C)CCC(O)C...      0
# 70  >Negative_190  CC(C)=CCCC(C)(OC1OC(COC2OCC(O)C(O)C2O)C(O)C(O)...      0
# 71  >Negative_191  CC(=O)OC1CCC2(C)C(C(O)CC3(C)C2CC(O)C2C(C(C)=CC...      0
# 72  >Negative_192  CC(C)=CCCC(C)(O)C1CCC2(C)C1C(O)CC1C3(C)CCC(O)C...      0
#
# [73 rows x 3 columns]

# %%
smiles_list = df['SMILES'].tolist()
smiles_list
len(smiles_list)
# Out:
# 73

# %%
#Write the elements of the list to a text file
with open('smiles.txt', 'w') as f:
    for item in smiles_list:
        f.write("%s\n" % item)

print("Data has been written to the text file.")
# Out:
# Data has been written to the text file.

# %%
ligand = iFeatureOmegaCLI.iLigand("./smiles.txt")

# %%
feature_type = ['EState', 'MACCS fingerprints', 'Morgan-ECFP4 fingerprints', 'Morgan-ECFP6 fingerprints', 'Morgan-FCFP4 fingerprints', 'Morgan-FCFP6 fingerprints']

# %%
for f in feature_type:
    ligand.get_descriptor(f)
    encodings_df = pd.DataFrame(ligand.encodings)
    encodings_df.reset_index(drop=True, inplace=True)
    merged_df = pd.concat([df['Sample ID'], encodings_df, df['Label']], axis=1)
    csv_filename = f"04_single_vs_multi_function_test_73_ifeatureomega_{f}.csv"
    merged_df.to_csv(csv_filename, index=False)
    print(f"CSV file saved: {csv_filename}")
# Out:
# /home/terrina/anaconda3/envs/my_rdkit_env/lib/python3.8/site-packages/iFeatureOmegaCLI/iFeatureOmegaCLI.py:9901: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[i, fp+str(j)] = c
# /home/terrina/anaconda3/envs/my_rdkit_env/lib/python3.8/site-packages/iFeatureOmegaCLI/iFeatureOmegaCLI.py:9901: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[i, fp+str(j)] = c
# ...
